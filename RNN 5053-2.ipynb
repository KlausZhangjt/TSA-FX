# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler


def process(path):
    """
    pre-processing TRI data
    for train set (1997-2020): 1.eliminate extreme values; 2. standardization
    for test set (2020-2022): rolling window standardization
    """
    df = pd.read_csv(path)
    tri = df.tri.values
    split_node = df[df['timestamp'].str.contains('2019')].index[-1]
    train = tri[:split_node+1]
    test = tri[split_node+1:]
    train = process_extreme_MAD(train).reshape(-1, 1)
    scaler = StandardScaler()
    scaler.fit(train)
    train = scaler.transform(train)
    test = rolling_standard(train.ravel(), test)
    return train, test
    
    
def process_extreme_MAD(array, n=3):
    """
    Deal with extreme values, use MAD method
    """
    mid = np.median(array)
    mid1 = np.median(np.abs(array - mid))
    maximum = mid + n * mid1
    minimum = mid - n * mid1
    return np.clip(array, minimum, maximum)
    

def rolling_standard(pre, cur, n=60):
    """
    rolling window standardization
    """
    new = np.concatenate([pre[-(n-1):], cur])
    df = pd.DataFrame(new)
    mean = df.rolling(n).apply(np.mean)
    std = df.rolling(n).apply(np.std)
    df1 = (df - mean) / std
    return df1[(n-1):].values
path = '/Users/wangsizhe/Desktop/AUD_v2.csv'
train,test = process(path)

# %%
training_set_scaled = train
testing_set_scaled = test

# %%
import pandas as pd 
 
# 加载数据集 
data = pd.read_csv('/Users/wangsizhe/Desktop/AUD_v2.csv')
data.drop(['underlyer','spot','carry','active','version'],axis=1,inplace=True)
 
# 将日期设置为索引 
data = data.set_index('timestamp')
# 显示前5行数据 
print(data.head())
# Out:
#                           tri
# timestamp
# 1997-03-19 19:00:00  0.000000
# 1997-03-20 19:00:00  0.090012
# 1997-03-21 19:00:00 -0.172836
# 1997-03-24 19:00:00  0.163459
# 1997-03-25 19:00:00  0.133008

# %%
import matplotlib.pyplot as plt 
 
# 绘制销售额随时间的变化图 
series = data
plt.figure(figsize=(10, 6))
 
series['tri'].plot()
plt.show()

# %%
# training_set = data.values
# # 训练数据max-min归一化
# from sklearn.preprocessing import MinMaxScaler
# sc = MinMaxScaler(feature_range = (0, 1))
# training_set_scaled = sc.fit_transform(training_set)

# %%
# 每条样本含60个时间步，对应下一时间步的标签值
X_train = []
y_train = []
for i in range(12, 5512):
    X_train.append(training_set_scaled[i-1:i, 0])
    y_train.append(training_set_scaled[i, 0])
X_train, y_train = np.array(X_train), np.array(y_train)
 
print(X_train.shape)
print(y_train.shape)
 
# Reshaping
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
print(X_train.shape)
# Out:
# (5500, 1)
# (5500,)
# (5500, 1, 1)

# %%
X_test = []
y_test = []
for i in range(12, 540):
    X_test.append(testing_set_scaled[i-1:i, 0])
    y_test.append(testing_set_scaled[i, 0])
X_test, y_test = np.array(X_test), np.array(y_test)
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
print(X_test.shape)
# Out:
# (528, 1, 1)

# %%
#  利用Keras创建RNN模型
 
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import SimpleRNN,LSTM
from keras.layers import Dropout
 
 
# 初始化顺序模型
regressor = Sequential()
 
# 定义输入层及带5个神经元的隐藏层
regressor.add(SimpleRNN(units = 5, input_shape = (X_train.shape[1], 1)))
 
# 定义线性的输出层
regressor.add(Dense(units = 1))
 
# 模型编译：定义优化算法adam， 目标函数均方根MSE
regressor.compile(optimizer = 'adam', loss = 'mean_squared_error')
 
# 模型训练
history = regressor.fit(X_train, y_train, epochs = 100, batch_size = 100, validation_split=0.1)
 
regressor.summary()
# Out:
# Epoch 1/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.2336 - val_loss: 0.1161
# Epoch 2/100
# 50/50 [==============================] - 0s 927us/step - loss: 0.1044 - val_loss: 0.0385
# Epoch 3/100
# 50/50 [==============================] - 0s 757us/step - loss: 0.0399 - val_loss: 0.0067
# Epoch 4/100
# 50/50 [==============================] - 0s 750us/step - loss: 0.0141 - val_loss: 3.8923e-04
# Epoch 5/100
# 50/50 [==============================] - 0s 767us/step - loss: 0.0063 - val_loss: 0.0013
# Epoch 6/100
# 50/50 [==============================] - 0s 763us/step - loss: 0.0046 - val_loss: 0.0030
# Epoch 7/100
# 50/50 [==============================] - 0s 831us/step - loss: 0.0042 - val_loss: 0.0033
# Epoch 8/100
# 50/50 [==============================] - 0s 743us/step - loss: 0.0041 - val_loss: 0.0033
# Epoch 9/100
# 50/50 [==============================] - 0s 761us/step - loss: 0.0040 - val_loss: 0.0032
# Epoch 10/100
# 50/50 [==============================] - 0s 780us/step - loss: 0.0039 - val_loss: 0.0031
# Epoch 11/100
# 50/50 [==============================] - 0s 755us/step - loss: 0.0038 - val_loss: 0.0033
# Epoch 12/100
# 50/50 [==============================] - 0s 742us/step - loss: 0.0037 - val_loss: 0.0032
# Epoch 13/100
# 50/50 [==============================] - 0s 755us/step - loss: 0.0036 - val_loss: 0.0031
# Epoch 14/100
# 50/50 [==============================] - 0s 792us/step - loss: 0.0035 - val_loss: 0.0029
# Epoch 15/100
# 50/50 [==============================] - 0s 746us/step - loss: 0.0034 - val_loss: 0.0027
# Epoch 16/100
# 50/50 [==============================] - 0s 759us/step - loss: 0.0033 - val_loss: 0.0029
# Epoch 17/100
# 50/50 [==============================] - 0s 843us/step - loss: 0.0033 - val_loss: 0.0032
# Epoch 18/100
# 50/50 [==============================] - 0s 764us/step - loss: 0.0032 - val_loss: 0.0027
# Epoch 19/100
# 50/50 [==============================] - 0s 758us/step - loss: 0.0031 - val_loss: 0.0026
# Epoch 20/100
# 50/50 [==============================] - 0s 773us/step - loss: 0.0030 - val_loss: 0.0025
# Epoch 21/100
# 50/50 [==============================] - 0s 742us/step - loss: 0.0030 - val_loss: 0.0025
# Epoch 22/100
# 50/50 [==============================] - 0s 789us/step - loss: 0.0029 - val_loss: 0.0025
# Epoch 23/100
# 50/50 [==============================] - 0s 813us/step - loss: 0.0028 - val_loss: 0.0021
# Epoch 24/100
# 50/50 [==============================] - 0s 767us/step - loss: 0.0027 - val_loss: 0.0022
# Epoch 25/100
# 50/50 [==============================] - 0s 791us/step - loss: 0.0027 - val_loss: 0.0024
# Epoch 26/100
# 50/50 [==============================] - 0s 752us/step - loss: 0.0026 - val_loss: 0.0020
# Epoch 27/100
# 50/50 [==============================] - 0s 755us/step - loss: 0.0025 - val_loss: 0.0022
# Epoch 28/100
# 50/50 [==============================] - 0s 752us/step - loss: 0.0025 - val_loss: 0.0018
# Epoch 29/100
# 50/50 [==============================] - 0s 777us/step - loss: 0.0024 - val_loss: 0.0019
# Epoch 30/100
# 50/50 [==============================] - 0s 758us/step - loss: 0.0023 - val_loss: 0.0017
# Epoch 31/100
# 50/50 [==============================] - 0s 754us/step - loss: 0.0023 - val_loss: 0.0019
# Epoch 32/100
# 50/50 [==============================] - 0s 793us/step - loss: 0.0022 - val_loss: 0.0019
# Epoch 33/100
# 50/50 [==============================] - 0s 770us/step - loss: 0.0022 - val_loss: 0.0016
# Epoch 34/100
# 50/50 [==============================] - 0s 768us/step - loss: 0.0021 - val_loss: 0.0019
# Epoch 35/100
# 50/50 [==============================] - 0s 760us/step - loss: 0.0021 - val_loss: 0.0019
# Epoch 36/100
# 50/50 [==============================] - 0s 743us/step - loss: 0.0020 - val_loss: 0.0016
# Epoch 37/100
# 50/50 [==============================] - 0s 776us/step - loss: 0.0019 - val_loss: 0.0012
# Epoch 38/100
# 50/50 [==============================] - 0s 764us/step - loss: 0.0019 - val_loss: 0.0015
# Epoch 39/100
# 50/50 [==============================] - 0s 753us/step - loss: 0.0018 - val_loss: 0.0015
# Epoch 40/100
# 50/50 [==============================] - 0s 764us/step - loss: 0.0018 - val_loss: 0.0014
# Epoch 41/100
# 50/50 [==============================] - 0s 770us/step - loss: 0.0017 - val_loss: 0.0014
# Epoch 42/100
# 50/50 [==============================] - 0s 757us/step - loss: 0.0017 - val_loss: 0.0014
# Epoch 43/100
# 50/50 [==============================] - 0s 774us/step - loss: 0.0017 - val_loss: 0.0013
# Epoch 44/100
# 50/50 [==============================] - 0s 770us/step - loss: 0.0016 - val_loss: 0.0012
# Epoch 45/100
# 50/50 [==============================] - 0s 756us/step - loss: 0.0016 - val_loss: 0.0010
# Epoch 46/100
# 50/50 [==============================] - 0s 769us/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 47/100
# 50/50 [==============================] - 0s 769us/step - loss: 0.0015 - val_loss: 0.0011
# Epoch 48/100
# 50/50 [==============================] - 0s 766us/step - loss: 0.0015 - val_loss: 0.0011
# Epoch 49/100
# 50/50 [==============================] - 0s 830us/step - loss: 0.0014 - val_loss: 0.0010
# Epoch 50/100
# 50/50 [==============================] - 0s 859us/step - loss: 0.0014 - val_loss: 0.0010
# Epoch 51/100
# 50/50 [==============================] - 0s 872us/step - loss: 0.0014 - val_loss: 0.0010
# Epoch 52/100
# 50/50 [==============================] - 0s 843us/step - loss: 0.0013 - val_loss: 0.0014
# Epoch 53/100
# 50/50 [==============================] - 0s 851us/step - loss: 0.0013 - val_loss: 0.0011
# Epoch 54/100
# 50/50 [==============================] - 0s 812us/step - loss: 0.0013 - val_loss: 9.3169e-04
# Epoch 55/100
# 50/50 [==============================] - 0s 822us/step - loss: 0.0013 - val_loss: 8.9270e-04
# Epoch 56/100
# 50/50 [==============================] - 0s 823us/step - loss: 0.0012 - val_loss: 0.0010
# Epoch
# 50/50 [==============================] - 0s 711us/step - loss: 8.5092e-04 - val_loss: 5.6302e-04
# Epoch 84/100
# 50/50 [==============================] - 0s 709us/step - loss: 8.4443e-04 - val_loss: 5.6506e-04
# Epoch 85/100
# 50/50 [==============================] - 0s 725us/step - loss: 8.4001e-04 - val_loss: 6.7703e-04
# Epoch 86/100
# 50/50 [==============================] - 0s 762us/step - loss: 8.2956e-04 - val_loss: 5.9765e-04
# Epoch 87/100
# 50/50 [==============================] - 0s 734us/step - loss: 8.2284e-04 - val_loss: 4.5708e-04
# Epoch 88/100
# 50/50 [==============================] - 0s 790us/step - loss: 8.1925e-04 - val_loss: 6.3399e-04
# Epoch 89/100
# 50/50 [==============================] - 0s 790us/step - loss: 8.1079e-04 - val_loss: 5.1271e-04
# Epoch 90/100
# 50/50 [==============================] - 0s 795us/step - loss: 8.0584e-04 - val_loss: 5.9977e-04
# Epoch 91/100
# 50/50 [==============================] - 0s 816us/step - loss: 7.9962e-04 - val_loss: 4.9804e-04
# Epoch 92/100
# 50/50 [==============================] - 0s 826us/step - loss: 7.9450e-04 - val_loss: 5.4416e-04
# Epoch 93/100
# 50/50 [==============================] - 0s 789us/step - loss: 7.8885e-04 - val_loss: 6.3731e-04
# Epoch 94/100
# 50/50 [==============================] - 0s 740us/step - loss: 7.8667e-04 - val_loss: 6.1634e-04
# Epoch 95/100
# 50/50 [==============================] - 0s 753us/step - loss: 7.7766e-04 - val_loss: 4.7896e-04
# Epoch 96/100
# 50/50 [==============================] - 0s 733us/step - loss: 7.7688e-04 - val_loss: 5.3731e-04
# Epoch 97/100
# 50/50 [==============================] - 0s 719us/step - loss: 7.7424e-04 - val_loss: 5.1680e-04
# Epoch 98/100
# 50/50 [==============================] - 0s 690us/step - loss: 7.6829e-04 - val_loss: 5.5053e-04
# Epoch 99/100
# 50/50 [==============================] - 0s 680us/step - loss: 7.5700e-04 - val_loss: 6.3011e-04
# Epoch 100/100
# 50/50 [==============================] - 0s 684us/step - loss: 7.6094e-04 - val_loss: 5.0383e-04
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_2 (SimpleRNN)    (None, 5)                 35
#
#  dense_2 (Dense)             (None, 1)                 6
#
# =================================================================
# Total params: 41
# Trainable params: 41
# Non-trainable params: 0
# _________________________________________________________________

# %%
plt.plot(history.history['loss'],c='blue')    # 蓝色线训练集损失
plt.plot(history.history['val_loss'],c='red') # 红色线验证集损失
plt.show()

# %%
real_stock_price = y_test

# %%
predicted_stock_price = regressor.predict(X_test)
predicted_stock_price = predicted_stock_price.reshape(1,-1)[0]
print('预测与实际差异MSE',sum(pow((predicted_stock_price - real_stock_price),2))/predicted_stock_price.shape[0])
print('预测与实际差异MAE',sum(abs(predicted_stock_price - real_stock_price))/predicted_stock_price.shape[0])
# Out:
# 17/17 [==============================] - 0s 567us/step
# 预测与实际差异MSE 0.12319220642053948
# 预测与实际差异MAE 0.25005136850512255

# %%
plt.plot(predicted_stock_price)
plt.plot(real_stock_price)
plt.legend(['true','pred'])
plt.show()

# %%
a = y_test[:-1]
b = predicted_stock_price[1:]
c = np.diff(y_test)
out = np.logical_or(
                    np.logical_and((b-a < 0),(c < 0)), 
                    np.logical_and((b-a > 0),(c > 0))
                                             )
sum(out)/len(a)
# Out:
# 0.5047438330170778
